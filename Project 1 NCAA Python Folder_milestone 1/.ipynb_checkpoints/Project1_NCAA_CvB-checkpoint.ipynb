# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\ttesn\anaconda3\lib\site-packages (8.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\ttesn\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ttesn\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# get the required modules

from sqlalchemy import create_engine    # sqlalchemy connector
import os                               # get the environment variables
import pandas as pd                     # get the pandas
import numpy as np                      # get numpy

# %%
# set up the connection to the database

MYSQL_HOST = 'tinabrauneck.lmu.build'
MYSQL_USER = 'tinabrau_project_team'
MYSQL_PASSWORD = os.getenv('BSAN_Project_Password') # Store password in your local envirmonment variables
MYSQL_DB = 'tinabrau_NCAA'     

NCAA_connection = create_engine(f'mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}/{MYSQL_DB}')

# %%
# Read sas files into a df. 
# We have to clean 2022's file because it contains an extra column. We will drop the column before combining the files.

AY21_22_df = pd.read_sas('2022_CLEANME_Schools.sas7bdat', encoding = 'latin-1')
AY21_22_df.head()
# Out:
#      unitid     OPEID          institution_name             addr1_txt  \
# 0  100654.0  00100200  Alabama A & M University  4900 Meridian Street
# 1  100654.0  00100200  Alabama A & M University  4900 Meridian Street
# 2  100654.0  00100200  Alabama A & M University  4900 Meridian Street
# 3  100654.0  00100200  Alabama A & M University  4900 Meridian Street
# 4  100654.0  00100200  Alabama A & M University  4900 Meridian Street
#
#   addr2_txt city_txt state_cd zip_text  ClassificationCode  \
# 0       NaN   Normal       AL    35762                 2.0
# 1       NaN   Normal       AL    35762                 2.0
# 2       NaN   Normal       AL    35762                 2.0
# 3       NaN   Normal       AL    35762                 2.0
# 4       NaN   Normal       AL    35762                 2.0
#
#    classification_name  ...    EXP_MEN  EXP_WOMEN  TOTAL_EXP_MENWOMEN  \
# 0  NCAA Division I-FCS  ...   297153.0        NaN            297153.0
# 1  NCAA Division I-FCS  ...  1132578.0  1067456.0           2200034.0
# 2  NCAA Division I-FCS  ...  3437529.0        NaN           3437529.0
# 3  NCAA Division I-FCS  ...    59524.0        NaN             59524.0
# 4  NCAA Division I-FCS  ...        NaN   355614.0            355614.0
#
#    EXP_COED_MEN  EXP_COED_WOMEN TOTAL_EXP_COED  EXPENSE_MENALL  \
# 0           NaN             NaN            NaN        297153.0
# 1           NaN             NaN            NaN       1132578.0
# 2           NaN             NaN            NaN       3437529.0
# 3           NaN             NaN            NaN         59524.0
# 4           NaN             NaN            NaN             0.0
#
#    EXPENSE_WOMENALL  TOTAL_EXPENSE_ALL      Sports
# 0               0.0           297153.0    Baseball
# 1         1067456.0          2200034.0  Basketball
# 2               0.0          3437529.0    Football
# 3               0.0            59524.0        Golf
# 4          355614.0           355614.0      Soccer
#
# [5 rows x 129 columns]

# %%
Cleaned_AY21_22_df = AY21_22_df.drop(columns = ["OPEID"])
Cleaned_AY21_22_df.head()
# Out:
#      unitid          institution_name             addr1_txt addr2_txt  \
# 0  100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 1  100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 2  100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 3  100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 4  100654.0  Alabama A & M University  4900 Meridian Street       NaN
#
#   city_txt state_cd zip_text  ClassificationCode  classification_name  \
# 0   Normal       AL    35762                 2.0  NCAA Division I-FCS
# 1   Normal       AL    35762                 2.0  NCAA Division I-FCS
# 2   Normal       AL    35762                 2.0  NCAA Division I-FCS
# 3   Normal       AL    35762                 2.0  NCAA Division I-FCS
# 4   Normal       AL    35762                 2.0  NCAA Division I-FCS
#
#   ClassificationOther  ...    EXP_MEN  EXP_WOMEN  TOTAL_EXP_MENWOMEN  \
# 0                 NaN  ...   297153.0        NaN            297153.0
# 1                 NaN  ...  1132578.0  1067456.0           2200034.0
# 2                 NaN  ...  3437529.0        NaN           3437529.0
# 3                 NaN  ...    59524.0        NaN             59524.0
# 4                 NaN  ...        NaN   355614.0            355614.0
#
#    EXP_COED_MEN EXP_COED_WOMEN  TOTAL_EXP_COED  EXPENSE_MENALL  \
# 0           NaN            NaN             NaN        297153.0
# 1           NaN            NaN             NaN       1132578.0
# 2           NaN            NaN             NaN       3437529.0
# 3           NaN            NaN             NaN         59524.0
# 4           NaN            NaN             NaN             0.0
#
#    EXPENSE_WOMENALL  TOTAL_EXPENSE_ALL      Sports
# 0               0.0           297153.0    Baseball
# 1         1067456.0          2200034.0  Basketball
# 2               0.0          3437529.0    Football
# 3               0.0            59524.0        Golf
# 4          355614.0           355614.0      Soccer
#
# [5 rows x 128 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 AY21_22_df.insert(0, "year", year)
#       2 AY21_22_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert year, already exists

# %%
# declare starting year as variable

year = 2010

# %%
# initialize an empty list for years and dataframes

years = []
dfs = []

# %%
for x in range(12):
    loop_year = year + x
    years.append(loop_year)

# %%
print(years)
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
# initialize a dataframe for all years, starting with the cleaned version of 2022

all_years_df = Cleaned_AY21_22_df

# %%
Cleaned_AY21_22_df.shape
# Out:
# (17644, 128)

# %%
# append the all_years_df with each year of data

for y in years:
    file_name_str = str(year)+'_schools.sas7bdat'
    temp_df = pd.read_sas(file_name_str, encoding = 'latin-1')
    temp_df.insert(0, "year", y)
    all_years_df = pd.concat([all_years_df, temp_df])
# Out:
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)
# C:\Users\ttesn\AppData\Local\Temp\ipykernel_24000\1793252226.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_df.insert(0, "year", y)

# %%
#2007-2009 files are messed up
temp_df = pd.read_sas('2012_schools.sas7bdat', encoding = 'latin-1')

# %%
all_years_df
# Out:
#          unitid          institution_name             addr1_txt addr2_txt  \
# 0      100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 1      100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 2      100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 3      100654.0  Alabama A & M University  4900 Meridian Street       NaN
# 4      100654.0  Alabama A & M University  4900 Meridian Street       NaN
# ...         ...                       ...                   ...       ...
# 16478  446048.0      Ave Maria University   5050 Ave Maria Blvd       NaN
# 16479  446048.0      Ave Maria University   5050 Ave Maria Blvd       NaN
# 16480  446048.0      Ave Maria University   5050 Ave Maria Blvd       NaN
# 16481  446233.0          Ecclesia College       9653 Nations Dr       NaN
# 16482  446233.0          Ecclesia College       9653 Nations Dr       NaN
#
#          city_txt state_cd     zip_text  ClassificationCode  \
# 0          Normal       AL        35762                 2.0
# 1          Normal       AL        35762                 2.0
# 2          Normal       AL        35762                 2.0
# 3          Normal       AL        35762                 2.0
# 4          Normal       AL        35762                 2.0
# ...           ...      ...          ...                 ...
# 16478   Ave Maria       FL  341429505.0                10.0
# 16479   Ave Maria       FL  341429505.0                10.0
# 16480   Ave Maria       FL  341429505.0                10.0
# 16481  Springdale       AR      72762.0                15.0
# 16482  Springdale       AR      72762.0                15.0
#
#        classification_name ClassificationOther  ...  EXP_WOMEN  \
# 0      NCAA Division I-FCS                 NaN  ...        NaN
# 1      NCAA Division I-FCS                 NaN  ...  1067456.0
# 2      NCAA Division I-FCS                 NaN  ...        NaN
# 3      NCAA Division I-FCS                 NaN  ...        NaN
# 4      NCAA Division I-FCS                 NaN  ...   355614.0
# ...                    ...                 ...  ...        ...
# 16478     NAIA Division II                 NaN  ...    94223.0
# 16479     NAIA Division II                 NaN  ...   105066.0
# 16480     NAIA Division II                 NaN  ...   177263.0
# 16481     NCCAA Division I                 NaN  ...        NaN
# 16482     NCCAA Division I                 NaN  ...    90684.0
#
#        TOTAL_EXP_MENWOMEN  EXP_COED_MEN  EXP_COED_WOMEN TOTAL_EXP_COED  \
# 0                297153.0           NaN             NaN            NaN
# 1               2200034.0           NaN             NaN            NaN
# 2               3437529.0           NaN             NaN            NaN
# 3                 59524.0           NaN             NaN            NaN
# 4                355614.0           NaN             NaN            NaN
# ...                   ...           ...             ...            ...
# 16478            224762.0           NaN             NaN            NaN
# 16479            105066.0           NaN             NaN            NaN
# 16480            177263.0           NaN             NaN            NaN
# 16481             13137.0           NaN             NaN            NaN
# 16482            211003.0           NaN             NaN            NaN
#
#        EXPENSE_MENALL  EXPENSE_WOMENALL  TOTAL_EXPENSE_ALL      Sports    year
# 0            297153.0               0.0           297153.0    Baseball     NaN
# 1           1132578.0         1067456.0          2200034.0  Basketball     NaN
# 2           3437529.0               0.0          3437529.0    Football     NaN
# 3             59524.0               0.0            59524.0        Golf     NaN
# 4                 0.0          355614.0           355614.0      Soccer     NaN
# ...               ...               ...                ...         ...     ...
# 16478        130539.0           94223.0           224762.0      Soccer  2021.0
# 16479             0.0          105066.0           105066.0    Softball  2021.0
# 16480             0.0          177263.0           177263.0  Volleyball  2021.0
# 16481         13137.0               0.0            13137.0    Baseball  2021.0
# 16482        120319.0           90684.0           211003.0  Basketball  2021.0
#
# [215440 rows x 129 columns]

# %%
# Combine sas files into one dataframe

all_years_df = pd.concat(dfs)

# %%
Schools_table = all_years_df.iloc[:,np.r_[2:11,15:16]]
Schools_table
# Out:
#                institution_name              addr1_txt  \
# 0      Alabama A & M University   4900 Meridian Street
# 1      Alabama A & M University   4900 Meridian Street
# 2      Alabama A & M University   4900 Meridian Street
# 3      Alabama A & M University   4900 Meridian Street
# 4      Alabama A & M University   4900 Meridian Street
# ...                         ...                    ...
# 17639   Simon Fraser University  8888 University Drive
# 17640   Simon Fraser University  8888 University Drive
# 17641   Simon Fraser University  8888 University Drive
# 17642   Simon Fraser University  8888 University Drive
# 17643   Simon Fraser University  8888 University Drive
#
#                           addr2_txt city_txt state_cd zip_text  \
# 0                               NaN   Normal       AL    35762
# 1                               NaN   Normal       AL    35762
# 2                               NaN   Normal       AL    35762
# 3                               NaN   Normal       AL    35762
# 4                               NaN   Normal       AL    35762
# ...                             ...      ...      ...      ...
# 17639  Burnaby, BC, V5A 1S6, Canada      NaN      NaN      NaN
# 17640  Burnaby, BC, V5A 1S6, Canada      NaN      NaN      NaN
# 17641  Burnaby, BC, V5A 1S6, Canada      NaN      NaN      NaN
# 17642  Burnaby, BC, V5A 1S6, Canada      NaN      NaN      NaN
# 17643  Burnaby, BC, V5A 1S6, Canada      NaN      NaN      NaN
#
#        ClassificationCode             classification_name ClassificationOther  \
# 0                     2.0             NCAA Division I-FCS                 NaN
# 1                     2.0             NCAA Division I-FCS                 NaN
# 2                     2.0             NCAA Division I-FCS                 NaN
# 3                     2.0             NCAA Division I-FCS                 NaN
# 4                     2.0             NCAA Division I-FCS                 NaN
# ...                   ...                             ...                 ...
# 17639                 4.0  NCAA Division II with football                 NaN
# 17640                 4.0  NCAA Division II with football                 NaN
# 17641                 4.0  NCAA Division II with football                 NaN
# 17642                 4.0  NCAA Division II with football                 NaN
# 17643                 4.0  NCAA Division II with football                 NaN
#
#                    sector_name
# 0      Public, 4-year or above
# 1      Public, 4-year or above
# 2      Public, 4-year or above
# 3      Public, 4-year or above
# 4      Public, 4-year or above
# ...                        ...
# 17639                      NaN
# 17640                      NaN
# 17641                      NaN
# 17642                      NaN
# 17643                      NaN
#
# [17644 rows x 10 columns]

# %%
Schools_table.to_sql(name='Schools', con=NCAA_connection, if_exists='replace', index=False)

# the first one is the name of the table.  con is the connection that has all the credentials.  if_exists can be either replace
# that would create or replace the file, or append that would actually add the rows.  Index = False will not write the index
# of the dataframe in the first column of the table.
# Out:
# 64

# %%
# Setting up SQL for any queries

testSQL = """
    SELECT DISTINCT City, State
    FROM e_beauty_clean_data
    ;
                  """

# %%
# define the parameters as dictionary

params = {}

# %%
sql_df = pd.read_sql_query(testSQL, con=practice_connection, params = params)
sql_df
# Out:
#                City State
# 0        New Castle    DE
# 1        Wilmington    DE
# 2        Prattville    AL
# 3         Lafayette    AL
# 4           Madison    AL
# ...             ...   ...
# 3205     Graysville    OH
# 3206       Girdwood    AK
# 3207         Bisbee    AZ
# 3208         Oxford    NJ
# 3209  Princess Anne    VA
#
# [3210 rows x 2 columns]
